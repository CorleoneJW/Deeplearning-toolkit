# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False


# define categories
# x_categories = ['clientBC_fully','clientAC_fully','clientAB_fully','clientA_partially','clientB_partially','clientC_partially','clientABC_fully']
x_categories = ['client_23','client_13','client_12','P1','P2','P3','client_123']
y_categories = ['spleen_A','liver_A','stomach_A','pancreas_A','spleen_B','liver_B','stomach_B','pancreas_B','spleen_C','liver_C','stomach_C','pancreas_C','spleen_D','liver_D','stomach_D','pancreas_D']
# y_categories = ['FLARE22_spleen','FLARE22_liver','FLARE22_stomach','FLARE22_pancreas','TCIA_spleen','TCIA_liver','TCIA_stomach','TCIA_pancreas','AMOS_spleen','AMOS_liver','AMOS_stomach','AMOS_pancreas','Synapse_spleen','Synapse_liver','Synapse_stomach','Synapse_pancreas']
# x_categories = ['clientBC_fully','clientAC_fully','clientAB_fully','clientA_partially','clientB_partially','clientC_partially','clientABC_fully']
# y_categories = ['FLARE22_spleen','FLARE22_liver','FLARE22_stomach','FLARE22_pancreas','TCIA_spleen','TCIA_liver','TCIA_stomach']
# define data
data = [
    [0.9081, 0.9392, 0.9448, 0.7373, 0.9113, 0.9165, 0.9532],
    [0.9498, 0.9607, 0.9700, 0.9346, 0.9550, 0.9609, 0.9632],
    [0.5493, 0.7139, 0.8337, 0.8713, 0.8505, 0.8599, 0.8477],
    [0.6140, 0.6606, 0.6816, 0.7058, 0.6753, 0.7296, 0.7001],

    [0.9699, 0.9628, 0.9246, 0.9636, 0.9610, 0.9548, 0.9696],
    [0.9552, 0.9487, 0.8469, 0.9613, 0.9526, 0.9563, 0.9534],
[0.4973, 0.6656, 0.5214, 0.7265, 0.7546, 0.7359, 0.7234],
[0.4949, 0.5509, 0.5902, 0.6059, 0.5832, 0.6329, 0.6536],

[0.7518, 0.8015, 0.6297, 0.6969, 0.7729, 0.5347, 0.8283],
[0.8976, 0.9106, 0.8846, 0.9233, 0.8987, 0.8866, 0.9118],
[0.6053, 0.5537, 0.5240, 0.6463, 0.6213, 0.6360, 0.6695],
[0.5184, 0.4999, 0.4020, 0.5366, 0.4923, 0.5462, 0.5297],

[0.8982, 0.9585, 0.9065, 0.8695, 0.8577, 0.8103, 0.8975],
[0.9553, 0.8751, 0.9427, 0.9477, 0.9451, 0.9399, 0.9589],
[0.6839, 0.5962, 0.6975, 0.7754, 0.7866, 0.7514, 0.7848],
[0.6820, 0.6993, 0.6616, 0.7332, 0.7764, 0.7457, 0.7722],
]

# create DataFrame
df = pd.DataFrame(data, index=y_categories, columns=x_categories)

# create heatmap
plt.figure(figsize=(10, 7))
plt.xticks(fontproperties='Times New Roman',fontsize=15, rotation=45)
# set the font size of ticks
plt.yticks(fontproperties='Times New Roman',fontsize=15)
sns.heatmap(df, annot=True, annot_kws={"size": 14}, cmap='RdYlBu_r')
plt.subplots_adjust(left=0.2, bottom=0.15, right=1.0, top=0.98)
plt.savefig('./example/heatmap.png')
plt.show()
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...
